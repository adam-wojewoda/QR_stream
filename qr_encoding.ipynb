# %%
import qrcode
# import zxing
from qrtools import qrtools
from os import path
import compress.api as compress
from tqdm.notebook import tqdm
from PIL import Image
from pyzbar.pyzbar import decode

# %%
def bin_to_qr(data, chunk_size=100,folder_path = None ,filename_prefix="qr_code", box_size=1, border=10):
    compressed_data = compress_bytes(data)
    hex_data = compressed_data.hex()    
    chunks = [hex_data[i:i+chunk_size] for i in range(0, len(hex_data), chunk_size)]
    total_chunks = len(chunks)

    for i, chunk in enumerate(tqdm(chunks), 1):
        qr = qrcode.QRCode(version=40, error_correction=qrcode.constants.ERROR_CORRECT_L, box_size=box_size, border=border)
        qr.add_data(f"{i}/{total_chunks}:{chunk}")
        qr.make(fit=False)
        print(f"Generating QR code {i}", end="")
        img = qr.make_image(fill_color="black", back_color="white")
        out_path = path.join(folder_path, f"{filename_prefix}_{i}.png")
        img.save(out_path)
        print(f"[OK]")

    print(f"Generated {total_chunks} QR codes.")
    print(f"Each QR code except the last one will contain {chunk_size} bytes of data.")
    print(f"The last QR code will contain the remaining bytes of data ({len(chunks[-1]  )} bytes).")

def qr_to_bin(folder_path = None,filename_prefix="qr_code"):
    chunks = {}
    i = 1
    # reader = zxing.BarCodeReader()
    # fallback_reader = qrtools.QR
    

    while True:
        try:
            filename = path.join(folder_path, f"{filename_prefix}_{i}.png")
            print(f"Decoding QR code {i}...")
            # print(filename)
            # barcode = reader.decode(filename)
            decoded = decode(Image.open(filename))[0].data.decode("utf-8")


            
            print(f"decoded...", end="")
            # if barcode and barcode.parsed:
            #     decoded = barcode.parsed
            # else:
            #     print(f"Could not decode QR code {i}: {barcode.raw} with zxing, trying fallback reader...")
                
            # split the decoded string into chunk_info and chunk_data
            chunk_info, chunk_data = decoded.split(':', 1)
            chunk_num, total_chunks = map(int, chunk_info.split('/'))
            chunks[chunk_num] = chunk_data
            # print(chunk_data)
            print(f"binary data extracted [OK]")
            if chunk_num == total_chunks:
                break
                # print(fallback_reader.data)
            if not chunks[i]:
                print(f"Error decoding QR code {i}")
                exit(-1)
            print(f"binary data extracted [OK]")

            i += 1
        except FileNotFoundError:
            break
        except Exception as e:
            print(f"Error decoding QR code {i}: {e}")
            raise e
            exit(-1)

    if not chunks:
        print("No QR codes found.")
        return None

    hex_data_compressed = ''.join(chunks[i] for i in range(1, len(chunks) + 1))
    bytes_compressed = bytes.fromhex(hex_data_compressed)
    return bytes_compressed

# Compressing as much as possible

def compress_bytes(data):
    data_compressed = compress.compress(
    algo=compress.Algorithm.gzip,
    data=data,
    kwargs={"compresslevel": 9})
    return data_compressed

def decompress_bytes(data):
    # compressor = Compressor()
    # compressor.use_gzip()
    return compress.decompress(algo=compress.Algorithm.gzip,data=data, kwargs={"compresslevel": 9})

# %%
with open("test_file.JPG", "rb") as f:
    data = f.read()

bin_to_qr(data, folder_path='out_path/'  ,chunk_size=2048, box_size=1, border=5)
# Out:
#   0%|          | 0/4232 [00:00<?, ?it/s]
# Generating QR code 1[OK]
# Generating QR code 2[OK]
# Generating QR code 3[OK]
# Generating QR code 4[OK]
# Generating QR code 5[OK]
# Generating QR code 6[OK]
# Generating QR code 7[OK]
# Generating QR code 8[OK]
# Generating QR code 9[OK]
# Generating QR code 10[OK]
# Generating QR code 11[OK]
# Generating QR code 12[OK]
# Generating QR code 13[OK]
# Generating QR code 14[OK]
# Generating QR code 15[OK]
# Generating QR code 16[OK]
# Generating QR code 17[OK]
# Generating QR code 18[OK]
# Generating QR code 19[OK]
# Generating QR code 20[OK]
# Generating QR code 21[OK]
# Generating QR code 22[OK]
# Generating QR code 23[OK]
# Generating QR code 24[OK]
# Generating QR code 25[OK]
# Generating QR code 26[OK]
# Generating QR code 27[OK]
# Generating QR code 28[OK]
# Generating QR code 29[OK]
# Generating QR code 30[OK]
# Generating QR code 31[OK]
# Generating QR code 32[OK]
# Generating QR code 33[OK]
# Generating QR code 34[OK]
# Generating QR code 35[OK]
# Generating QR code 36[OK]
# Generating QR code 37[OK]
# Generating QR code 38[OK]
# Generating QR code 39[OK]
# Generating QR code 40[OK]
# Generating QR code 41[OK]
# Generating QR code 42[OK]
# Generating QR code 43[OK]
# Generating QR code 44[OK]
# Generating QR code 45[OK]
# Generating QR code 46[OK]
# Generating QR code 47[OK]
# Generating QR code 48[OK]
# Generating QR code 49[OK]
# Generating QR code 50[OK]
# Generating QR code 51[OK]
# Generating QR code 52[OK]
# Generating QR code 53[OK]
# Generating QR code 54[OK]
# Generating QR code 55[OK]
# Generating QR code 56[OK]
# Generating QR code 57[OK]
# Generating QR code 58[OK]
# Generating QR code 59[OK]
# Generating QR code 60[OK]
# Generating QR code 61[OK]
# Generating QR code 62[OK]
# Generating QR code 63[OK]
# Generating QR code 64[OK]
# Generating QR code 65[OK]
# Generating QR code 66[OK]
# Generating QR code 67[OK]
# Generating QR code 68[OK]
# Generating QR code 69[OK]
# Generating QR code 70[OK]
# Generating QR code 71[OK]
# Generating QR code 72[OK]
# Generating QR code 73[OK]
# Generating QR code 74[OK]
# Generating QR code 75[OK]
# Generating QR code 76[OK]
# Generating QR code 77[OK]
# Generating QR code 78[OK]
# Generating QR code 79[OK]
# Generating QR code 80[OK]
# Generating QR code 81[OK]
# Generating QR code 82[OK]
# Generating QR code 83[OK]
# Generating QR code 84[OK]
# Generating QR code 85[OK]
# Generating QR code 86[OK]
# Generating QR code 87[OK]
# Generating QR code 88[OK]
# Generating QR code 89[OK]
# Generating QR code 90[OK]
# Generating QR code 91[OK]
# Generating QR code 92[OK]
# Generating QR code 93[OK]
# Generating QR code 94[OK]
# Generating QR code 95[OK]
# Generating QR code 96[OK]
# Generating QR code 97[OK]
# Generating QR code 98[OK]
# Generating QR code 99[OK]
# Generating QR code 100[OK]
# Generating QR code 101[OK]
# Generating QR code 102[OK]
# Generating QR code 103[OK]
# Generating QR code 104[OK]
# Generating QR code 105[OK]
# Generating QR code 106[OK]
# Generating QR code 107[OK]
# Generating QR code 108[OK]
# Generating QR code 109[OK]
# Generating QR code 110[OK]
# Generating QR code 111[OK]
# Generating QR code 112[OK]
# Generating QR code 113[OK]
# Generating QR code 114[OK]
# Generating QR code 115[OK]
# Generating QR code 116[OK]
# Generating QR code 117[OK]
# Generating QR code 118[OK]
# Generating QR code 119[OK]
# Generating QR code 120[OK]
# Generating QR code 121[OK]
# Generating QR code 122[OK]
# Generating QR code 123[OK]
# Generating QR code 124[OK]
# Generating QR code 125[OK]
# Generating QR code 126[OK]
# Generating QR code 127[OK]
# Generating QR code 128[OK]
# Generating QR code 129[OK]
# Generating QR code 130[OK]
# Generating QR code 131[OK]
# Generating QR code 132[OK]
# Generating QR code 133[OK]
# Generating QR code 134[OK]
# Generating QR code 135[OK]
# Generating QR code 136[OK]
# Generating QR code 137[OK]
# Generating QR code 138[OK]
# Generating QR code 139[OK]
# Generating QR code 140[OK]
# Generating QR code 141[OK]
# Generating QR code 142[OK]
# Generating QR code 143[OK]
# Generating QR code 144[OK]
# Generating QR code 145[OK]
# Generating QR code 146[OK]
# Generating QR code 147[OK]
# Generating QR code 148[OK]
# Generating QR code 149[OK]
# Generating QR code 150[OK]
# Generating QR code 151[OK]
# Generating QR code 152[OK]
# Generating QR code 153[OK]
# Generating QR code 154[OK]
# Generating QR code 155[OK]
# Generating QR code 156[OK]
# Generating QR code 157[OK]
# Generating QR code 158[OK]
# Generating QR code 159[OK]
# Generating QR code 160[OK]
# Generating QR code 161[OK]
# Generating QR code 162[OK]
# Generating QR code 163[OK]
# Generating QR code 164[OK]
# Generating QR code 165[OK]
# Generating QR code 166[OK]
# Generating QR code 167[OK]
# Generating QR code 168[OK]
# Generating QR code 169[OK]
# Generating QR code 170[OK]
# Generating QR code 171[OK]
# Generating QR code 172[OK]
# Generating QR code 173[OK]
# Generating QR code 174[OK]
# Generating QR code 175[OK]
# Generating QR code 176[OK]
# Generating QR code 177[OK]
# Generating QR code 178[OK]
# Generating QR code 179[OK]
# Generating QR code 180[OK]
# Generating QR code 181[OK]
# Generating QR code 182[OK]
# Generating QR code 183[OK]
# Generating QR code 184[OK]
# Generating QR code 185[OK]
# Generating QR code 186[OK]
# Generating QR code 187[OK]
# Generating QR code 188[OK]
# Generating QR code 189[OK]
# Generating QR code 190[OK]
# Generating QR code 191[OK]
# Generating QR code 192[OK]
# Generating QR code 193[OK]
# Generating QR code 194[OK]
# Generating QR code 195[OK]
# Generating QR code 196[OK]
# Generating QR code 197[OK]
# Generating QR code 198[OK]
# Generating QR code 199[OK]
# Generating QR code 200[OK]
# Generating QR code 201[OK]
# Generating QR code 202[OK]
# Generating QR code 203[OK]
# Generating QR code 204[OK]
# Generating QR code 205[OK]
# Generating QR code 206[OK]
# Generating QR code 207[OK]
# Generating QR code 208[OK]
# Generating QR code 209[OK]
# Generating QR code 210[OK]
# Generating QR code 211[OK]
# Generating QR code 212[OK]
# Generating QR code 213[OK]
# Generating QR code 214[OK]
# Generating QR code 215[OK]
# Generating QR code 216[OK]
# Generating QR code 217[OK]
# Generating QR code 218[OK]
# Generating QR code 219[OK]
# Generating QR code 220[OK]
# Generating QR code 221[OK]
# Generating QR code 222[OK]
# Generating QR code 223[OK]
# Generating QR code 224[OK]
# Generating QR code 225[OK]
# Generating QR code 226[OK]
# Generating QR code 227[OK]
# Generating QR code 228[OK]
# Generating QR code 229[OK]
# Generating QR code 230[OK]
# Generating QR code 231[OK]
# Generating QR code 232[OK]
# Generating QR code 233[OK]
# Generating QR code 234[OK]
# Generating QR code 235[OK]
# Generating QR code 236[OK]
# Generating QR code 237[OK]
# Generating QR code 238[OK]
# Generating QR code 239[OK]
# Generating QR code 240[OK]
# Generating QR code 241[OK]
# Generating QR code 242[OK]
# Generating QR code 243[OK]
# Generating QR code 244[OK]
# Generating QR code 245[OK]
# Generating QR code 246[OK]
# Generating QR code 247[OK]
# Generating QR code 248[OK]
# Generating QR code 249[OK]
# Generating QR code 250[OK]
# Generating QR code 251[OK]
# Generating QR code 252[OK]
# Generating QR code 253[OK]
# Generating QR code 254[OK]
# Generating QR code 255[OK]
# Generating QR code 256[OK]
# Generating QR code 257[OK]
# Generating QR code 258[OK]
# Generating QR code 259[OK]
# Generating QR code 260[OK]
# Generating QR code 261[OK]
# Generating QR code 262[OK]
# Generating QR code 263[OK]
# Generating QR code 264[OK]
# Generating QR code 265[OK]
# Generating QR code 266[OK]
# Generating QR code 267[OK]
# Generating QR code 268[OK]
# Generating QR code 269[OK]
# Generating QR code 270[OK]
# Generating QR code 271[OK]
# Generating QR code 272[OK]
# Generating QR code 273[OK]
# Generating QR code 274[OK]
# Generating QR code 275[OK]
# Generating QR code 276[OK]
# Generating QR code 277[OK]
# Generating QR code 278[OK]
# Generating QR code 279[OK]
# Generating QR code 280[OK]
# Generating QR code 281[OK]
# Generating QR code 282[OK]
# Generating QR code 283[OK]
# Generating QR code 284[OK]
# Generating QR code 285[OK]
# Generating QR code 286[OK]
# Generating QR code 287[OK]
# Generating QR code 288[OK]
# Generating QR code 289[OK]
# Generating QR code 290[OK]
# Generating QR code 291[OK]
# Generating QR code 292[OK]
# Generating QR code 293[OK]
# Generating QR code 294[OK]
# Generating QR code 295[OK]
# Generating QR code 296[OK]
# Generating QR code 297[OK]
# Generating QR code 298[OK]
# Generating QR code 299[OK]
# Generating QR code 300[OK]
# Generating QR code 301[OK]
# Generating QR code 302[OK]
# Generating QR code 303[OK]
# Generating QR code 304[OK]
# Generating QR code 305[OK]
# Generating QR code 306[OK]
# Generating QR code 307[OK]
# Generating QR code 308[OK]
# Generating QR code 309[OK]
# Generating QR code 310[OK]
# Generating QR code 311[OK]
# Generating QR code 312[OK]
# Generating QR code 313[OK]
# Generating QR code 314[OK]
# Generating QR code 315[OK]
# Generating QR code 316[OK]
# Generating QR code 317[OK]
# Generating QR code 318[OK]
# Generating QR code 319[OK]
# Generating QR code 320[OK]
# Generating QR code 321[OK]
# Generating QR code 322[OK]
# Generating QR code 323[OK]
# Generating QR code 324[OK]
# Generating QR code 325[OK]
# Generating QR code 326[OK]
# Generating QR code 327[OK]
# Generating QR code 328[OK]
# Generating QR code 329[OK]
# Generating QR code 330[OK]
# Generating QR code 331[OK]
# Generating QR code 332[OK]
# Generating QR code 333[OK]
# Generating QR code 334[OK]
# Generating QR code 335[OK]
# Generating QR code 336[OK]
# Generating QR code 337[OK]
# Generating QR code 338[OK]
# Generating QR code 339[OK]
# Generating QR code 340[OK]
# Generating QR code 341[OK]
# Generating QR code 342[OK]
# Generating QR code 343[OK]
# Generating QR code 344[OK]
# Generating QR code 345[OK]
# Generating QR code 346[OK]
# Generating QR code 347[OK]
# Generating QR code 348[OK]
# Generating QR code 349[OK]
# Generating QR code 350[OK]
# Generating QR code 351[OK]
# Generating QR code 352[OK]
# Generating QR code 353[OK]
# Generating QR code 354[OK]
# Generating QR code 355[OK]
# Generating QR code 356[OK]
# Generating QR code 357[OK]
# Generating QR code 358[OK]
# Generating QR code 359[OK]
# Generating QR code 360[OK]
# Generating QR code 361[OK]
# Generating QR code 362[OK]
# Generating QR code 363[OK]
# Generating QR code 364[OK]
# Generating QR code 365[OK]
# Generating QR code 366[OK]
# Generating QR code 367[OK]
# Generating QR code 368[OK]
# Generating QR code 369[OK]
# Generating QR code 370[OK]
# Generating QR code 371[OK]
# Generating QR code 372[OK]
# Generating QR code 373[OK]
# Generating QR code 374[OK]
# Generating QR code 375[OK]
# Generating QR code 376[OK]
# Generating QR code 377[OK]
# Generating QR code 378[OK]
# Generating QR code 379[OK]
# Generating QR code 380[OK]
# Generating QR code 381[OK]
# Generating QR code 382[OK]
# Generating QR code 383[OK]
# Generating QR code 384[OK]
# Generating QR code 385[OK]
# Generating QR code 386[OK]
# Generating QR code 387[OK]
# Generating QR code 388[OK]
# Generating QR code 389[OK]
# Generating QR code 390[OK]
# Generating QR code 391[OK]
# Generating QR code 392[OK]
# Generating QR code 393[OK]
# Generating QR code 394[OK]
# Generating QR code 395[OK]
# Generating QR code 396[OK]
# Generating QR code 397[OK]
# Generating QR code 398[OK]
# Generating QR code 399[OK]
# Generating QR code 400[OK]
# Generating QR code 401[OK]
# Generating QR code 402[OK]
# Generating QR code 403[OK]
# Generating QR code 404[OK]
# Generating QR code 405[OK]
# Generating QR code 406[OK]
# Generating QR code 407[OK]
# Generating QR code 408[OK]
# Generating QR code 409[OK]
# Generating QR code 410[OK]
# Generating QR code 411[OK]
# Generating QR code 412[OK]
# Generating QR code 413[OK]
# Generating QR code 414[OK]
# Generating QR code 415[OK]
# Generating QR code 416[OK]
# Generating QR code 417[OK]
# Generating QR code 418[OK]
# Generating QR code 419[OK]
# Generating QR code 420[OK]
# Generating QR code 421[OK]
# Generating QR code 422[OK]
# Generating QR code 423[OK]
# Generating QR code 424[OK]
# Generating QR code 425[OK]
# Generating QR code 426[OK]
# Generating QR code 427[OK]
# Generating QR code 428[OK]
# Generating QR code 429[OK]
# Generating QR code 430[OK]
# Generating QR code 431[OK]
# Generating QR code 432[OK]
# Generating QR code 433[OK]
# Generating QR code 434[OK]
# Generating QR code 435[OK]
# Generating QR code 436[OK]
# Generating QR code 437[OK]
# Generating QR code 438[OK]
# Generating QR code 439[OK]
# Generating QR code 440[OK]
# Generating QR code 441[OK]
# Generating QR code 442[OK]
# Generating QR code 443[OK]
# Generating QR code 444[OK]
# Generating QR code 445[OK]
# Generating QR code 446[OK]
# Generating QR code 447[OK]
# Generating QR code 448[OK]
# Generating QR code 449[OK]
# Generating QR code 450[OK]
# Generating QR code 451[OK]
# Generating QR code 452[OK]
# Generating QR code 453[OK]
# Generating QR code 454[OK]
# Generating QR code 455[OK]
# Generating QR code 456[OK]
# Generating QR code 457[OK]
# Generating QR code 458[OK]
# Generating QR code 459[OK]
# Generating QR code 460[OK]
# Generating QR code 461[OK]
# Generating QR code 462[OK]
# Generating QR code 463[OK]
# Generating QR code 464[OK]
# Generating QR code 465[OK]
# Generating QR code 466[OK]
# Generating QR code 467[OK]
# Generating QR code 468[OK]
# Generating QR code 469[OK]
# Generating QR code 470[OK]
# Generating QR code 471[OK]
# Generating QR code 472[OK]
# Generating QR code 473[OK]
# Generating QR code 474[OK]
# Generating QR code 475[OK]
# Generating QR code 476[OK]
# Generating QR code 477[OK]
# Generating QR code 478[OK]
# Generating QR code 479[OK]
# Generating QR code 480[OK]
# Generating QR code 481[OK]
# Generating QR code 482[OK]
# Generating QR code 483[OK]
# Generating QR code 484[OK]
# Generating QR code 485[OK]
# Generating QR code 486[OK]
# Generating QR code 487[OK]
# Generating QR code 488[OK]
# Generating QR code 489[OK]
# Generating QR code 490[OK]
# Generating QR code 491[OK]
# Generating QR code 492[OK]
# Generating QR code 493[OK]
# Generating QR code 494[OK]
# Generating QR code 495[OK]
# Generating QR code 496[OK]
# Generating QR code 497[OK]
# Generating QR code 498[OK]
# Generating QR code 499[OK]
# Generating QR code 500[OK]
# Generating QR code 501[OK]
# Generating QR code 502[OK]
# Generating QR code 503[OK]
# Generating QR code 504[OK]
# Generating QR code 505[OK]
# Generating QR code 506[OK]
# Generating QR code 507[OK]
# Generating QR code 508[OK]
# Generating QR code 509[OK]
# Generating QR code 510[OK]
# Generating QR code 511[OK]
# Generating QR code 512[OK]
# Generating QR code 513[OK]
# Generating QR code 514[OK]
# Generating QR code 515[OK]
# Generating QR code 516[OK]
# Generating QR code 517[OK]
# Generating QR code 518[OK]
# Generating QR code 519[OK]
# Generating QR code 520[OK]
# Generating QR code 521[OK]
# Generating QR code 522[OK]
# Generating QR code 523[OK]
# Generating QR code 524[OK]
# Generating QR code 525[OK]
# Generating QR code 526[OK]
# Generating QR code 527[OK]
# Generating QR code 528[OK]
# Generating QR code 529[OK]
# Generating QR code 530[OK]
# Generating QR code 531[OK]
# Generating QR code 532[OK]
# Generating QR code 533[OK]
# Generating QR code 534[OK]
# Generating QR code 535[OK]
# Generating QR code 536[OK]
# Generating QR code 537[OK]
# Generating QR code 538[OK]
# Generating QR code 539[OK]
# Generating QR code 540[OK]
# Generating QR code 541[OK]
# Generating QR code 542[OK]
# Generating QR code 543[OK]
# Generating QR code 544[OK]
# Generating QR code 545[OK]
# Generating QR code 546[OK]
# Generating QR code 547[OK]
# Generating QR code 548[OK]
# Generating QR code 549[OK]
# Generating QR code 550[OK]
# Generating QR code 551[OK]
# Generating QR code 552[OK]
# Generating QR code 553[OK]
# Generating QR code 554[OK]
# Generating QR code 555[OK]
# Generating QR code 556[OK]
# Generating QR code 557[OK]
# Generating QR code 558[OK]
# Generating QR code 559[OK]
# Generating QR code 560[OK]
# Generating QR code 561[OK]
# Generating QR code 562[OK]
# Generating QR code 563[OK]
# Generating QR code 564[OK]
# Generating QR code 565[OK]
# Generating QR code 566[OK]
# Generating QR code 567[OK]
# Generating QR code 568[OK]
# Generating QR code 569[OK]
# Generating QR code 570[OK]
# Generating QR code 571[OK]
# Generating QR code 572[OK]
# Generating QR code 573[OK]
# Generating QR code 574[OK]
# Generating QR code 575[OK]
# Generating QR code 576[OK]
# Generating QR code 577[OK]
# Generating QR code 578[OK]
# Generating QR code 579[OK]
# Generating QR code 580[OK]
# Generating QR code 581[OK]
# Generating QR code 582[OK]
# Generating QR code 583[OK]
# Generating QR code 584[OK]
# Generating QR code 585[OK]
# Generating QR code 586[OK]
# Generating QR code 587[OK]
# Generating QR code 588[OK]
# Generating QR code 589[OK]
# Generating QR code 590[OK]
# Generating QR code 591[OK]
# Generating QR code 592[OK]
# Generating QR code 593[OK]
# Generating QR code 594[OK]
# Generating QR code 595[OK]
# Generating QR code 596[OK]
# Generating QR code 597[OK]
# Generating QR code 598[OK]
# Generating QR code 599[OK]
# Generating QR code 600[OK]
# Generating QR code 601[OK]
# Generating QR code 602[OK]
# Generating QR code 603[OK]
# Generating QR code 604[OK]
# Generating QR code 605[OK]
# Generating QR code 606[OK]
# Generating QR code 607[OK]
# Generating QR code 608[OK]
# Generating QR code 609[OK]
# Generating QR code 610[OK]
# Generating QR code 611[OK]
# Generating QR code 612[OK]
# Generating QR code 613[OK]
# Generating QR code 614[OK]
# Generating QR code 615[OK]
# Generating QR code 616[OK]
# Generating QR code 617[OK]
# Generating QR code 618[OK]
# Generating QR code 619[OK]
# Generating QR code 620[OK]
# Generating QR code 621[OK]
# Generating QR code 622[OK]
# Generating QR code 623[OK]
# Generating QR code 624[OK]
# Generating QR code 625[OK]
# Generating QR code 626[OK]
# Generating QR code 627[OK]
# Generating QR code 628[OK]
# Generating QR code 629[OK]
# Generating QR code 630[OK]
# Generating QR code 631[OK]
# Generating QR code 632[OK]
# Generating QR code 633[OK]
# Generating QR code 634[OK]
# Generating QR code 635[OK]
# Generating QR code 636[OK]
# Generating QR code 637[OK]
# Generating QR code 638[OK]
# Generating QR code 639[OK]
# Generating QR code 640[OK]
# Generating QR code 641[OK]
# Generating QR code 642[OK]
# Generating QR code 643[OK]
# Generating QR code 644[OK]
# Generating QR code 645[OK]
# Generating QR code 646[OK]
# Generating QR code 647[OK]
# Generating QR code 648[OK]
# Generating QR code 649[OK]
# Generating QR code 650[OK]
# Generating QR code 651[OK]
# Generating QR code 652[OK]
# Generating QR code 653[OK]
# Generating QR code 654[OK]
# Generating QR code 655[OK]
# Generating QR code 656[OK]
# Generating QR code 657[OK]
# Generating QR code 658[OK]
# Generating QR code 659[OK]
# Generating QR code 660[OK]
# Generating QR code 661[OK]
# Generating QR code 662[OK]
# Generating QR code 663[OK]
# Generating QR code 664[OK]
# Generating QR code 665[OK]
# Generating QR code 666[OK]
# Generating QR code 667[OK]
# Generating QR code 668[OK]
# Generating QR code 669[OK]
# Generating QR code 670[OK]
# Generating QR code 671[OK]
# Generating QR code 672[OK]
# Generating QR code 673[OK]
# Generating QR code 674[OK]
# Generating QR code 675[OK]
# Generating QR code 676[OK]
# Generating QR code 677[OK]
# Generating QR code 678[OK]
# Generating QR code 679[OK]
# Generating QR code 680[OK]
# Generating QR code 681[OK]
# Generating QR code 682[OK]
# Generating QR code 683[OK]
# Generating QR code 684[OK]
# Generating QR code 685[OK]
# Generating QR code 686[OK]
# Generating QR code 687[OK]
# Generating QR code 688[OK]
# Generating QR code 689[OK]
# Generating QR code 690[OK]
# Generating QR code 691[OK]
# Generating QR code 692[OK]
# Generating QR code 693[OK]
# Generating QR code 694[OK]
# Generating QR code 695[OK]
# Generating QR code 696[OK]
# Generating QR code 697[OK]
# Generating QR code 698[OK]
# Generating QR code 699[OK]
# Generating QR code 700[OK]
# Generating QR code 701[OK]
# Generating QR code 702[OK]
# Generating QR code 703[OK]
# Generating QR code 704[OK]
# Generating QR code 705[OK]
# Generating QR code 706[OK]
# Generating QR code 707[OK]
# Generating QR code 708[OK]
# Generating QR code 709[OK]
# Generating QR code 710[OK]
# Generating QR code 711[OK]
# Generating QR code 712[OK]
# Generating QR code 713[OK]
# Generating QR code 714[OK]
# Generating QR code 715[OK]
# Generating QR code 716[OK]
# Generating QR code 717[OK]
# Generating QR code 718[OK]
# Generating QR code 719[OK]
# Generating QR code 720[OK]
# Generating QR code 721[OK]
# Generating QR code 722[OK]
# Generating QR code 723[OK]
# Generating QR code 724[OK]
# Generating QR code 725[OK]
# Generating QR code 726[OK]
# Generating QR code 727[OK]
# Generating QR code 728[OK]
# Generating QR code 729[OK]
# Generating QR code 730[OK]
# Generating QR code 731[OK]
# Generating QR code 732[OK]
# Generating QR code 733[OK]
# Generating QR code 734[OK]
# Generating QR code 735[OK]
# Generating QR code 736[OK]
# Generating QR code 737[OK]
# Generating QR code 738[OK]
# Generating QR code 739[OK]
# Generating QR code 740[OK]
# Generating QR code 741[OK]
# Generating QR code 742[OK]
# Generating QR code 743[OK]
# Generating QR code 744[OK]
# Generating QR code 745[OK]
# Generating QR code 746[OK]
# Generating QR code 747[OK]
# Generating QR code 748[OK]
# Generating QR code 749[OK]
# Generating QR code 750[OK]
# Generating QR code 751[OK]
# Generating QR code 752[OK]
# Generating QR code 753[OK]
# Generating QR code 754[OK]
# Generating QR code 755[OK]
# Generating QR code 756[OK]
# Generating QR code 757[OK]
# Generating QR code 758[OK]
# Generating QR code 759[OK]
# Generating QR code 760[OK]
# Generating QR code 761[OK]
# Generating QR code 762[OK]
# Generating QR code 763[OK]
# Generating QR code 764[OK]
# Generating QR code 765[OK]
# Generating QR code 766[OK]
# Generating QR code 767[OK]
# Generating QR code 768[OK]
# Generating QR code 769[OK]
# Generating QR code 770[OK]
# Generating QR code 771[OK]
# Generating QR code 772[OK]
# Generating QR code 773[OK]
# Generating QR code 774[OK]
# Generating QR code 775[OK]
# Generating QR code 776[OK]
# Generating QR code 777[OK]
# Generating QR code 778[OK]
# Generating QR code 779[OK]
# Generating QR code 780[OK]
# Generating QR code 781[OK]
# Generating QR code 782[OK]
# Generating QR code 783[OK]
# Generating QR code 784[OK]
# Generating QR code 785[OK]
# Generating QR code 786[OK]
# Generating QR code 787[OK]
# Generating QR code 788[OK]
# Generating QR code 789[OK]
# Generating QR code 790[OK]
# Generating QR code 791[OK]
# Generating QR code 792[OK]
# Generating QR code 793[OK]
# Generating QR code 794[OK]
# Generating QR code 795[OK]
# Generating QR code 796[OK]
# Generating QR code 797[OK]
# Generating QR code 798[OK]
# Generating QR code 799[OK]
# Generating QR code 800[OK]
# Generating QR code 801[OK]
# Generating QR code 802[OK]
# Generating QR code 803[OK]
# Generating QR code 804[OK]
# Generating QR code 805[OK]
# Generating QR code 806[OK]
# Generating QR code 807[OK]
# Generating QR code 808[OK]
# Generating QR code 809[OK]
# Generating QR code 810[OK]
# Generating QR code 811[OK]
# Generating QR code 812[OK]
# Generating QR code 813[OK]
# Generating QR code 814[OK]
# Generating QR code 815[OK]
# Generating QR code 816[OK]
# Generating QR code 817[OK]
# Generating QR code 818[OK]
# Generating QR code 819[OK]
# Generating QR code 820[OK]
# Generating QR code 821[OK]
# Generating QR code 822[OK]
# Generating QR code 823[OK]
# Generating QR code 824[OK]
# Generating QR code 825[OK]
# Generating QR code 826[OK]
# Generating QR code 827[OK]
# Generating QR code 828[OK]
# Generating QR code 829[OK]
# Generating QR code 830[OK]
# Generating QR code 831[OK]
# Generating QR code 832[OK]
# Generating QR code 833[OK]
# Generating QR code 834[OK]
# Generating QR code 835[OK]
# Generating QR code 836[OK]
# Generating QR code 837[OK]
# Generating QR code 838[OK]
# Generating QR code 839[OK]
# Generating QR code 840[OK]
# Generating QR code 841[OK]
# Generating QR code 842[OK]
# Generating QR code 843[OK]
# Generating QR code 844[OK]
# Generating QR code 845[OK]
# Generating QR code 846[OK]
# Generating QR code 847[OK]
# Generating QR code 848[OK]
# Generating QR code 849[OK]
# Generating QR code 850[OK]
# Generating QR code 851[OK]
# Generating QR code 852[OK]
# Generating QR code 853[OK]
# Generating QR code 854[OK]
# Generating QR code 855[OK]
# Generating QR code 856[OK]
# Generating QR code 857[OK]
# Generating QR code 858[OK]
# Generating QR code 859[OK]
# Generating QR code 860[OK]
# Generating QR code 861[OK]
# Generating QR code 862[OK]
# Generating QR code 863[OK]
# Generating QR code 864[OK]
# Generating QR code 865[OK]
# Generating QR code 866[OK]
# Generating QR code 867[OK]
# Generating QR code 868[OK]
# Generating QR code 869[OK]
# Generating QR code 870[OK]
# Generating QR code 871[OK]
# Generating QR code 872[OK]
# Generating QR code 873[OK]
# Generating QR code 874[OK]
# Generating QR code 875[OK]
# Generating QR code 876[OK]
# Generating QR code 877[OK]
# Generating QR code 878[OK]
# Generating QR code 879[OK]
# Generating QR code 880[OK]
# Generating QR code 881[OK]
# Generating QR code 882[OK]
# Generating QR code 883[OK]
# Generating QR code 884[OK]
# Generating QR code 885[OK]
# Generating QR code 886[OK]
# Generating QR code 887[OK]
# Generating QR code 888[OK]
# Generating QR code 889[OK]
# Generating QR code 890[OK]
# Generating QR code 891[OK]
# Generating QR code 892[OK]
# Generating QR code 893[OK]
# Generating QR code 894[OK]
# Generating QR code 895[OK]
# Generating QR code 896[OK]
# Generating QR code 897[OK]
# Generating QR code 898[OK]
# Generating QR code 899[OK]
# Generating QR code 900[OK]
# Generating QR code 901[OK]
# Generating QR code 902[OK]
# Generating QR code 903[OK]
# Generating QR code 904[OK]
# Generating QR code 905[OK]
# Generating QR code 906[OK]
# Generating QR code 907[OK]
# Generating QR code 908[OK]
# Generating QR code 909[OK]
# Generating QR code 910[OK]
# Generating QR code 911[OK]
# Generating QR code 912[OK]
# Generating QR code 913[OK]
# Generating QR code 914[OK]
# Generating QR code 915[OK]
# Generating QR code 916[OK]
# Generating QR code 917[OK]
# Generating QR code 918[OK]
# Generating QR code 919[OK]
# Generating QR code 920[OK]
# Generating QR code 921[OK]
# Generating QR code 922[OK]
# Generating QR code 923[OK]
# Generating QR code 924[OK]
# Generating QR code 925[OK]
# Generating QR code 926[OK]
# Generating QR code 927[OK]
# Generating QR code 928[OK]
# Generating QR code 929[OK]
# Generating QR code 930[OK]
# Generating QR code 931[OK]
# Generating QR code 932[OK]
# Generating QR code 933[OK]
# Generating QR code 934[OK]
# Generating QR code 935[OK]
# Generating QR code 936[OK]
# Generating QR code 937[OK]
# Generating QR code 938[OK]
# Generating QR code 939[OK]
# Generating QR code 940[OK]
# Generating QR code 941[OK]
# Generating QR code 942[OK]
# Generating QR code 943[OK]
# Generating QR code 944[OK]
# Generating QR code 945[OK]
# Generating QR code 946[OK]
# Generating QR code 947[OK]
# Generating QR code 948[OK]
# Generating QR code 949[OK]
# Generating QR code 950[OK]
# Generating QR code 951[OK]
# Generating QR code 952[OK]
# Generating QR code 953[OK]
# Generating QR code 954[OK]
# Generating QR code 955[OK]
# Generating QR code 956[OK]
# Generating QR code 957[OK]
# Generating QR code 958[OK]
# Generating QR code 959[OK]
# Generating QR code 960[OK]
# Generating QR code 961[OK]
# Generating QR code 962[OK]
# Generating QR code 963[OK]
# Generating QR code 964[OK]
# Generating QR code 965[OK]
# Generating QR code 966[OK]
# Generating QR code 967[OK]
# Generating QR code 968[OK]
# Generating QR code 969[OK]
# Generating QR code 970[OK]
# Generating QR code 971[OK]
# Generating QR code 972[OK]
# Generating QR code 973[OK]
# Generating QR code 974[OK]
# Generating QR code 975[OK]
# Generating QR code 976[OK]
# Generating QR code 977[OK]
# Generating QR code 978[OK]
# Generating QR code 979[OK]
# Generating QR code 980[OK]
# Generating QR code 981[OK]
# Generating QR code 982[OK]
# Generating QR code 983[OK]
# Generating QR code 984[OK]
# Generating QR code 985[OK]
# Generating QR code 986[OK]
# Generating QR code 987[OK]
# Generating QR code 988[OK]
# Generating QR code 989[OK]
# Generating QR code 990[OK]
# Generating QR code 991[OK]
# Generating QR code 992[OK]
# Generating QR code 993[OK]
# Generating QR code 994[OK]
# Generating QR code 995[OK]
# Generating QR code 996[OK]
# Generating QR code 997[OK]
# Generating QR code 998[OK]
# Generating QR code 999[OK]
# Generating QR code 1000[OK]
# Generating QR code 1001[OK]
# Generating QR code 1002[OK]
# Generating QR code 1003[OK]
# Generating QR code 1004[OK]
# Generating QR code 1005[OK]
# Generating QR code 1006[OK]
# Generating QR code 1007[OK]
# Generating QR code 1008[OK]
# Generating QR code 1009[OK]
# Generating QR code 1010[OK]
# Generating QR code 1011[OK]
# Generating QR code 1012[OK]
# Generating QR code 1013[OK]
# Generating QR code 1014[OK]
# Generating QR code 1015[OK]
# Generating QR code 1016[OK]
# Generating QR code 1017[OK]
# Generating QR code 1018[OK]
# Generating QR code 1019[OK]
# Generating QR code 1020[OK]
# Generating QR code 1021[OK]
# Generating QR code 1022[OK]
# Generating QR code 1023[OK]
# Generating QR code 1024[OK]
# Generating QR code 1025[OK]
# Generating QR code 1026[OK]
# Generating QR code 1027[OK]
# Generating QR code 1028[OK]
# Generating QR code 1029[OK]
# Generating QR code 1030[OK]
# Generating QR code 1031[OK]
# Generating QR code 1032[OK]
# Generating QR code 1033[OK]
# Generating QR code 1034[OK]
# Generating QR code 1035[OK]
# Generating QR code 1036[OK]
# Generating QR code 1037[OK]
# Generating QR code 1038[OK]
# Generating QR code 1039[OK]
# Generating QR code 1040[OK]
# Generating QR code 1041[OK]
# Generating QR code 1042[OK]
# Generating QR code 1043[OK]
# Generating QR code 1044[OK]
# Generating QR code 1045[OK]
# Generating QR code 1046[OK]
# Generating QR code 1047[OK]
# Generating QR code 1048[OK]
# Generating QR code 1049[OK]
# Generating QR code 1050[OK]
# Generating QR code 1051[OK]
# Generating QR code 1052[OK]
# Generating QR code 1053[OK]
# Generating QR code 1054[OK]
# Generating QR code 1055[OK]
# Generating QR code 1056[OK]
# Generating QR code 1057[OK]
# Generating QR code 1058[OK]
# Generating QR code 1059[OK]
# Generating QR code 1060[OK]
# Generating QR code 1061[OK]
# Generating QR code 1062[OK]
# Generating QR code 1063[OK]
# Generating QR code 1064[OK]
# Generating QR code 1065[OK]
# Generating QR code 1066[OK]
# Generating QR code 1067[OK]
# Generating QR code 1068[OK]
# Generating QR code 1069[OK]
# Generating QR code 1070[OK]
# Generating QR code 1071[OK]
# Generating QR code 1072[OK]
# Generating QR code 1073[OK]
# Generating QR code 1074[OK]
# Generating QR code 1075[OK]
# Generating QR code 1076[OK]
# Generating QR code 1077[OK]
# Generating QR code 1078[OK]
# Generating QR code 1079[OK]
# Generating QR code 1080[OK]
# Generating QR code 1081[OK]
# Generating QR code 1082[OK]
# Generating QR code 1083[OK]
# Generating QR code 1084[OK]
# Generating QR code 1085[OK]
# Generating QR code 1086[OK]
# Generating QR code 1087[OK]
# Generating QR code 1088[OK]
# Generating QR code 1089[OK]
# Generating QR code 1090[OK]
# Generating QR code 1091[OK]
# Generating QR code 1092[OK]
# Generating QR code 1093[OK]
# Generating QR code 1094[OK]
# Generating QR code 1095[OK]
# Generating QR code 1096[OK]
# Generating QR code 1097[OK]
# Generating QR code 1098[OK]
# Generating QR code 1099[OK]
# Generating QR code 1100[OK]
# Generating QR code 1101[OK]
# Generating QR code 1102[OK]
# Generating QR code 1103[OK]
# Generating QR code 1104[OK]
# Generating QR code 1105[OK]
# Generating QR code 1106[OK]
# Generating QR code 1107[OK]
# Generating QR code 1108[OK]
# Generating QR code 1109[OK]
# Generating QR code 1110[OK]
# Generating QR code 1111[OK]
# Generating QR code 1112[OK]
# Generating QR code 1113[OK]
# Generating QR code 1114[OK]
# Generating QR code 1115[OK]
# Generating QR code 1116[OK]
# Generating QR code 1117[OK]
# Generating QR code 1118[OK]
# Generating QR code 1119[OK]
# Generating QR code 1120[OK]
# Generating QR code 1121[OK]
# Generating QR code 1122[OK]
# Generating QR code 1123[OK]
# Generating QR code 1124[OK]
# Generating QR code 1125[OK]
# Generating QR code 1126[OK]
# Generating QR code 1127[OK]
# Generating QR code 1128[OK]
# Generating QR code 1129[OK]
# Generating QR code 1130[OK]
# Generating QR code 1131[OK]
# Generating QR code 1132[OK]
# Generating QR code 1133[OK]
# Generating QR code 1134[OK]
# Generating QR code 1135[OK]
# Generating QR code 1136[OK]
# Generating QR code 1137[OK]
# Generating QR code 1138[OK]
# Generating QR code 1139[OK]
# Generating QR code 1140[OK]
# Generating QR code 1141[OK]
# Generating QR code 1142[OK]
# Generating QR code 1143[OK]
# Generating QR code 1144[OK]
# Generating QR code 1145[OK]
# Generating QR code 1146[OK]
# Generating QR code 1147[OK]
# Generating QR code 1148[OK]
# Generating QR code 1149[OK]
# Generating QR code 1150[OK]
# Generating QR code 1151[OK]
# Generating QR code 1152[OK]
# Generating QR code 1153[OK]
# Generating QR code 1154[OK]
# Generating QR code 1155[OK]
# Generating QR code 1156[OK]
# Generating QR code 1157[OK]
# Generating QR code 1158[OK]
# Generating QR code 1159[OK]
# Generating QR code 1160[OK]
# Generating QR code 1161[OK]
# Generating QR code 1162[OK]
# Generating QR code 1163[OK]
# Generating QR code 1164[OK]
# Generating QR code 1165[OK]
# Generating QR code 1166[OK]
# Generating QR code 1167[OK]
# Generating QR code 1168[OK]
# Generating QR code 1169[OK]
# Generating QR code 1170[OK]
# Generating QR code 1171[OK]
# Generating QR code 1172[OK]
# Generating QR code 1173[OK]
# Generating QR code 1174[OK]
# Generating QR code 1175[OK]
# Generating QR code 1176[OK]
# Generating QR code 1177[OK]
# Generating QR code 1178[OK]
# Generating QR code 1179[OK]
# Generating QR code 1180[OK]
# Generating QR code 1181[OK]
# Generating QR code 1182[OK]
# Generating QR code 1183[OK]
# Generating QR code 1184[OK]
# Generating QR code 1185[OK]
# Generating QR code 1186[OK]
# Generating QR code 1187[OK]
# Generating QR code 1188[OK]
# Generating QR code 1189[OK]
# Generating QR code 1190[OK]
# Generating QR code 1191[OK]
# Generating QR code 1192[OK]
# Generating QR code 1193[OK]
# Generating QR code 1194[OK]
# Generating QR code 1195[OK]
# Generating QR code 1196[OK]
# Generating QR code 1197[OK]
# Generating QR code 1198[OK]
# Generating QR code 1199[OK]
# Generating QR code 1200[OK]
# Generating QR code 1201[OK]
# Generating QR code 1202[OK]
# Generating QR code 1203[OK]
# Generating QR code 1204[OK]
# Generating QR code 1205[OK]
# Generating QR code 1206[OK]
# Generating QR code 1207[OK]
# Generating QR code 1208[OK]
# Generating QR code 1209[OK]
# Generating QR code 1210[OK]
# Generating QR code 1211[OK]
# Generating QR code 1212[OK]
# Generating QR code 1213[OK]
# Generating QR code 1214[OK]
# Generating QR code 1215[OK]
# Generating QR code 1216[OK]
# Generating QR code 1217[OK]
# Generating QR code 1218[OK]
# Generating QR code 1219[OK]
# Generating QR code 1220[OK]
# Generating QR code 1221[OK]
# Generating QR code 1222[OK]
# Generating QR code 1223[OK]
# Generating QR code 1224[OK]
# Generating QR code 1225[OK]
# Generating QR code 1226[OK]
# Generating QR code 1227[OK]
# Generating QR code 1228[OK]
# Generating QR code 1229[OK]
# Generating QR code 1230[OK]
# Generating QR code 1231[OK]
# Generating QR code 1232[OK]
# Generating QR code 1233[OK]
# Generating QR code 1234[OK]
# Generating QR code 1235[OK]
# Generating QR code 1236[OK]
# Generating QR code 1237[OK]
# Generating QR code 1238[OK]
# Generating QR code 1239[OK]
# Generating QR code 1240[OK]
# Generating QR code 1241[OK]
# Generating QR code 1242[OK]
# Generating QR code 1243[OK]
# Generating QR code 1244[OK]
# Generating QR code 1245[OK]
# Generating QR code 1246[OK]
# Generating QR code 1247[OK]
# Generating QR code 1248[OK]
# Generating QR code 1249[OK]
# Generating QR code 1250[OK]
# Generating QR code 1251[OK]
# Generating QR code 1252[OK]
# Generating QR code 1253[OK]
# Generating QR code 1254[OK]
# Generating QR code 1255[OK]
# Generating QR code 1256[OK]
# Generating QR code 1257[OK]
# Generating QR code 1258[OK]
# Generating QR code 1259[OK]
# Generating QR code 1260[OK]
# Generating QR code 1261[OK]
# Generating QR code 1262[OK]
# Generating QR code 1263[OK]
# Generating QR code 1264[OK]
# Generating QR code 1265[OK]
# Generating QR code 1266[OK]
# Generating QR code 1267[OK]
# Generating QR code 1268[OK]
# Generating QR code 1269[OK]
# Generating QR code 1270[OK]
# Generating QR code 1271[OK]
# Generating QR code 1272[OK]
# Generating QR code 1273[OK]
# Generating QR code 1274[OK]
# Generating QR code 1275[OK]
# Generating QR code 1276[OK]
# Generating QR code 1277[OK]
# Generating QR code 1278[OK]
# Generating QR code 1279[OK]
# Generating QR code 1280[OK]
# Generating QR code 1281[OK]
# Generating QR code 1282[OK]
# Generating QR code 1283[OK]
# Generating QR code 1284[OK]
# Generating QR code 1285[OK]
# Generating QR code 1286[OK]
# Generating QR code 1287[OK]
# Generating QR code 1288[OK]
# Generating QR code 1289[OK]
# Generating QR code 1290[OK]
# Generating QR code 1291[OK]
# Generating QR code 1292[OK]
# Generating QR code 1293[OK]
# Generating QR code 1294[OK]
# Generating QR code 1295[OK]
# Generating QR code 1296[OK]
# Generating QR code 1297[OK]
# Generating QR code 1298[OK]
# Generating QR code 1299[OK]
# Generating QR code 1300[OK]
# Generating QR code 1301[OK]
# Generating QR code 1302[OK]
# Generating QR code 1303[OK]
# Generating QR code 1304[OK]
# Generating QR code 1305[OK]
# Generating QR code 1306[OK]
# Generating QR code 1307[OK]
# Generating QR code 1308[OK]
# Generating QR code 1309[OK]
# Generating QR code 1310[OK]
# Generating QR code 1311[OK]
# Generating QR code 1312[OK]
# Generating QR code 1313[OK]
# Generating QR code 1314[OK]
# Generating QR code 1315[OK]
# Generating QR code 1316[OK]
# Generating QR code 1317[OK]
# Generating QR code 1318[OK]
# Generating QR code 1319[OK]
# Generating QR code 1320[OK]
# Generating QR code 1321[OK]
# Generating QR code 1322[OK]
# Generating QR code 1323[OK]
# Generating QR code 1324[OK]
# Generating QR code 1325[OK]
# Generating QR code 1326[OK]
# Generating QR code 1327[OK]
# Generating QR code 1328[OK]
# Generating QR code 1329[OK]
# Generating QR code 1330[OK]
# Generating QR code 1331[OK]
# Generating QR code 1332[OK]
# Generating QR code 1333[OK]
# Generating QR code 1334[OK]
# Generating QR code 1335[OK]
# Generating QR code 1336[OK]
# Generating QR code 1337[OK]
# Generating QR code 1338[OK]
# Generating QR code 1339[OK]
# Generating QR code 1340[OK]
# Generating QR code 1341[OK]
# Generating QR code 1342[OK]
# Generating QR code 1343[OK]
# Generating QR code 1344[OK]
# Generating QR code 1345[OK]
# Generating QR code 1346[OK]
# Generating QR code 1347[OK]
# Generating QR code 1348[OK]
# Generating QR code 1349[OK]
# Generating QR code 1350[OK]
# Generating QR code 1351[OK]
# Generating QR code 1352[OK]
# Generating QR code 1353[OK]
# Generating QR code 1354[OK]
# Generating QR code 1355[OK]
# Generating QR code 1356[OK]
# Generating QR code 1357[OK]
# Generating QR code 1358[OK]
# Generating QR code 1359[OK]
# Generating QR code 1360[OK]
# Generating QR code 1361[OK]
# Generating QR code 1362[OK]
# Generating QR code 1363[OK]
# Generating QR code 1364[OK]
# Generating QR code 1365[OK]
# Generating QR code 1366[OK]
# Generating QR code 1367[OK]
# Generating QR code 1368[OK]
# Generating QR code 1369[OK]
# Generating QR code 1370[OK]
# Generating QR code 1371[OK]
# Generating QR code 1372[OK]
# Generating QR code 1373[OK]
# Generating QR code 1374[OK]
# Generating QR code 1375[OK]
# Generating QR code 1376[OK]
# Generating QR code 1377[OK]
# Generating QR code 1378[OK]
# Generating QR code 1379[OK]
# Generating QR code 1380[OK]
# Generating QR code 1381[OK]
# Generating QR code 1382[OK]
# Generating QR code 1383[OK]
# Generating QR code 1384[OK]
# Generating QR code 1385[OK]
# Generating QR code 1386[OK]
# Generating QR code 1387[OK]
# Generating QR code 1388[OK]
# Generating QR code 1389[OK]
# Generating QR code 1390[OK]
# Generating QR code 1391[OK]
# Generating QR code 1392[OK]
# Generating QR code 1393[OK]
# Generating QR code 1394[OK]
# Generating QR code 1395[OK]
# Generating QR code 1396[OK]
# Generating QR code 1397[OK]
# Generating QR code 1398[OK]
# Generating QR code 1399[OK]
# Generating QR code 1400[OK]
# Generating QR code 1401[OK]
# Generating QR code 1402[OK]
# Generating QR code 1403[OK]
# Generating QR code 1404[OK]
# Generating QR code 1405[OK]
# Generating QR code 1406[OK]
# Generating QR code 1407[OK]
# Generating QR code 1408[OK]
# Generating QR code 1409[OK]
# Generating QR code 1410[OK]
# Generating QR code 1411[OK]
# Generating QR code 1412[OK]
# Generating QR code 1413[OK]
# Generating QR code 1414[OK]
# Generating QR code 1415[OK]
# Generating QR code 1416[OK]
# Generating QR code 1417[OK]
# Generating QR code 1418[OK]
# Generating QR code 1419[OK]
# Generating QR code 1420[OK]
# Generating QR code 1421[OK]
# Generating QR code 1422[OK]
# Generating QR code 1423[OK]
# Generating QR code 1424[OK]
# Generating QR code 1425[OK]
# Generating QR code 1426[OK]
# Generating QR code 1427[OK]
# Generating QR code 1428[OK]
# Generating QR code 1429[OK]
# Generating QR code 1430[OK]
# Generating QR code 1431[OK]
# Generating QR code 1432[OK]
# Generating QR code 1433[OK]
# Generating QR code 1434[OK]
# Generating QR code 1435[OK]
# Generating QR code 1436[OK]
# Generating QR code 1437[OK]
# Generating QR code 1438[OK]
# Generating QR code 1439[OK]
# Generating QR code 1440[OK]
# Generating QR code 1441[OK]
# Generating QR code 1442[OK]
# Generating QR code 1443[OK]
# Generating QR code 1444[OK]
# Generating QR code 1445[OK]
# Generating QR code 1446[OK]
# Generating QR code 1447[OK]
# Generating QR code 1448[OK]
# Generating QR code 1449[OK]
# Generating QR code 1450[OK]
# Generating QR code 1451[OK]
# Generating QR code 1452[OK]
# Generating QR code 1453[OK]
# Generating QR code 1454[OK]
# Generating QR code 1455[OK]
# Generating QR code 1456[OK]
# Generating QR code 1457[OK]
# Generating QR code 1458[OK]
# Generating QR code 1459[OK]
# Generating QR code 1460[OK]
# Generating QR code 1461[OK]
# Generating QR code 1462[OK]
# Generating QR code 1463[OK]
# Generating QR code 1464[OK]
# Generating QR code 1465[OK]
# Generating QR code 1466[OK]
# Generating QR code 1467[OK]
# Generating QR code 1468[OK]
# Generating QR code 1469[OK]
# Generating QR code 1470[OK]
# Generating QR code 1471[OK]
# Generating QR code 1472[OK]
# Generating QR code 1473[OK]
# Generating QR code 1474[OK]
# Generating QR code 1475[OK]
# Generating QR code 1476[OK]
# Generating QR code 1477[OK]
# Generating QR code 1478[OK]
# Generating QR code 1479[OK]
# Generating QR code 1480[OK]
# Generating QR code 1481[OK]
# Generating QR code 1482[OK]
# Generating QR code 1483[OK]
# Generating QR code 1484[OK]
# Generating QR code 1485[OK]
# Generating QR code 1486[OK]
# Generating QR code 1487[OK]
# Generating QR code 1488[OK]
# Generating QR code 1489[OK]
# Generating QR code 1490[OK]
# Generating QR code 1491[OK]
# Generating QR code 1492[OK]
# Generating QR code 1493[OK]
# Generating QR code 1494[OK]
# Generating QR code 1495[OK]
# Generating QR code 1496[OK]
# Generating QR code 1497[OK]
# Generating QR code 1498[OK]
# Generating QR code 1499[OK]
# Generating QR code 1500[OK]
# Generating QR code 1501[OK]
# Generating QR code 1502[OK]
# Generating QR code 1503[OK]
# Generating QR code 1504[OK]
# Generating QR code 1505[OK]
# Generating QR code 1506[OK]
# Generating QR code 1507[OK]
# Generating QR code 1508[OK]
# Generating QR code 1509[OK]
# Generating QR code 1510[OK]
# Generating QR code 1511[OK]
# Generating QR code 1512[OK]
# Generating QR code 1513[OK]
# Generating QR code 1514[OK]
# Generating QR code 1515[OK]
# Generating QR code 1516[OK]
# Generating QR code 1517[OK]
# Generating QR code 1518[OK]
# Generating QR code 1519[OK]
# Generating QR code 1520[OK]
# Generating QR code 1521[OK]
# Generating QR code 1522[OK]
# Generating QR code 1523[OK]
# Generating QR code 1524[OK]
# Generating QR code 1525[OK]
# Generating QR code 1526[OK]
# Generating QR code 1527[OK]
# Generating QR code 1528[OK]
# Generating QR code 1529[OK]
# Generating QR code 1530[OK]
# Generating QR code 1531[OK]
# Generating QR code 1532[OK]
# Generating QR code 1533[OK]
# Generating QR code 1534[OK]
# Generating QR code 1535[OK]
# Generating QR code 1536[OK]
# Generating QR code 1537[OK]
# Generating QR code 1538[OK]
# Generating QR code 1539[OK]
# Generating QR code 1540[OK]
# Generating QR code 1541[OK]
# Generating QR code 1542[OK]
# Generating QR code 1543[OK]
# Generating QR code 1544[OK]
# Generating QR code 1545[OK]
# Generating QR code 1546[OK]
# Generating QR code 1547[OK]
# Generating QR code 1548[OK]
# Generating QR code 1549[OK]
# Generating QR code 1550[OK]
# Generating QR code 1551[OK]
# Generating QR code 1552[OK]
# Generating QR code 1553[OK]
# Generating QR code 1554[OK]
# Generating QR code 1555[OK]
# Generating QR code 1556[OK]
# Generating QR code 1557[OK]
# Generating QR code 1558[OK]
# Generating QR code 1559[OK]
# Generating QR code 1560[OK]
# Generating QR code 1561[OK]
# Generating QR code 1562[OK]
# Generating QR code 1563[OK]
# Generating QR code 1564[OK]
# Generating QR code 1565[OK]
# Generating QR code 1566[OK]
# Generating QR code 1567[OK]
# Generating QR code 1568[OK]
# Generating QR code 1569[OK]
# Generating QR code 1570[OK]
# Generating QR code 1571[OK]
# Generating QR code 1572[OK]
# Generating QR code 1573[OK]
# Generating QR code 1574[OK]
# Generating QR code 1575[OK]
# Generating QR code 1576[OK]
# Generating QR code 1577[OK]
# Generating QR code 1578[OK]
# Generating QR code 1579[OK]
# Generating QR code 1580[OK]
# Generating QR code 1581[OK]
# Generating QR code 1582[OK]
# Generating QR code 1583[OK]
# Generating QR code 1584[OK]
# Generating QR code 1585[OK]
# Generating QR code 1586[OK]
# Generating QR code 1587[OK]
# Generating QR code 1588[OK]
# Generating QR code 1589[OK]
# Generating QR code 1590[OK]
# Generating QR code 1591[OK]
# Generating QR code 1592[OK]
# Generating QR code 1593[OK]
# Generating QR code 1594[OK]
# Generating QR code 1595[OK]
# Generating QR code 1596[OK]
# Generating QR code 1597[OK]
# Generating QR code 1598[OK]
# Generating QR code 1599[OK]
# Generating QR code 1600[OK]
# Generating QR code 1601[OK]
# Generating QR code 1602[OK]
# Generating QR code 1603[OK]
# Generating QR code 1604[OK]
# Generating QR code 1605[OK]
# Generating QR code 1606[OK]
# Generating QR code 1607[OK]
# Generating QR code 1608[OK]
# Generating QR code 1609[OK]
# Generating QR code 1610[OK]
# Generating QR code 1611[OK]
# Generating QR code 1612[OK]
# Generating QR code 1613[OK]
# Generating QR code 1614[OK]
# Generating QR code 1615[OK]
# Generating QR code 1616[OK]
# Generating QR code 1617[OK]
# Generating QR code 1618[OK]
# Generating QR code 1619[OK]
# Generating QR code 1620[OK]
# Generating QR code 1621[OK]
# Generating QR code 1622[OK]
# Generating QR code 1623[OK]
# Generating QR code 1624[OK]
# Generating QR code 1625[OK]
# Generating QR code 1626[OK]
# Generating QR code 1627[OK]
# Generating QR code 1628[OK]
# Generating QR code 1629[OK]
# Generating QR code 1630[OK]
# Generating QR code 1631[OK]
# Generating QR code 1632[OK]
# Generating QR code 1633[OK]
# Generating QR code 1634[OK]
# Generating QR code 1635[OK]
# Generating QR code 1636[OK]
# Generating QR code 1637[OK]
# Generating QR code 1638[OK]
# Generating QR code 1639[OK]
# Generating QR code 1640[OK]
# Generating QR code 1641[OK]
# Generating QR code 1642[OK]
# Generating QR code 1643[OK]
# Generating QR code 1644[OK]
# Generating QR code 1645[OK]
# Generating QR code 1646[OK]
# Generating QR code 1647[OK]
# Generating QR code 1648[OK]
# Generating QR code 1649[OK]
# Generating QR code 1650[OK]
# Generating QR code 1651[OK]
# Generating QR code 1652[OK]
# Generating QR code 1653[OK]
# Generating QR code 1654[OK]
# Generating QR code 1655[OK]
# Generating QR code 1656[OK]
# Generating QR code 1657[OK]
# Generating QR code 1658[OK]
# Generating QR code 1659[OK]
# Generating QR code 1660[OK]
# Generating QR code 1661[OK]
# Generating QR code 1662[OK]
# Generating QR code 1663[OK]
# Generating QR code 1664[OK]
# Generating QR code 1665[OK]
# Generating QR code 1666[OK]
# Generating QR code 1667[OK]
# Generating QR code 1668[OK]
# Generating QR code 1669[OK]
# Generating QR code 1670[OK]
# Generating QR code 1671[OK]
# Generating QR code 1672[OK]
# Generating QR code 1673[OK]
# Generating QR code 1674[OK]
# Generating QR code 1675[OK]
# Generating QR code 1676[OK]
# Generating QR code 1677[OK]
# Generating QR code 1678[OK]
# Generating QR code 1679[OK]
# Generating QR code 1680[OK]
# Generating QR code 1681[OK]
# Generating QR code 1682[OK]
# Generating QR code 1683[OK]
# Generating QR code 1684[OK]
# Generating QR code 1685[OK]
# Generating QR code 1686[OK]
# Generating QR code 1687[OK]
# Generating QR code 1688[OK]
# Generating QR code 1689[OK]
# Generating QR code 1690[OK]
# Generating QR code 1691[OK]
# Generating QR code 1692[OK]
# Generating QR code 1693[OK]
# Generating QR code 1694[OK]
# Generating QR code 1695[OK]
# Generating QR code 1696[OK]
# Generating QR code 1697[OK]
# Generating QR code 1698[OK]
# Generating QR code 1699[OK]
# Generating QR code 1700[OK]
# Generating QR code 1701[OK]
# Generating QR code 1702[OK]
# Generating QR code 1703[OK]
# Generating QR code 1704[OK]
# Generating QR code 1705[OK]
# Generating QR code 1706[OK]
# Generating QR code 1707[OK]
# Generating QR code 1708[OK]
# Generating QR code 1709[OK]
# Generating QR code 1710[OK]
# Generating QR code 1711[OK]
# Generating QR code 1712[OK]
# Generating QR code 1713[OK]
# Generating QR code 1714[OK]
# Generating QR code 1715[OK]
# Generating QR code 1716[OK]
# Generating QR code 1717[OK]
# Generating QR code 1718[OK]
# Generating QR code 1719[OK]
# Generating QR code 1720[OK]
# Generating QR code 1721[OK]
# Generating QR code 1722[OK]
# Generating QR code 1723[OK]
# Generating QR code 1724[OK]
# Generating QR code 1725[OK]
# Generating QR code 1726[OK]
# Generating QR code 1727[OK]
# Generating QR code 1728[OK]
# Generating QR code 1729[OK]
# Generating QR code 1730[OK]
# Generating QR code 1731[OK]
# Generating QR code 1732[OK]
# Generating QR code 1733[OK]
# Generating QR code 1734[OK]
# Generating QR code 1735[OK]
# Generating QR code 1736[OK]
# Generating QR code 1737[OK]
# Generating QR code 1738[OK]
# Generating QR code 1739[OK]
# Generating QR code 1740[OK]
# Generating QR code 1741[OK]
# Generating QR code 1742[OK]
# Generating QR code 1743[OK]
# Generating QR code 1744[OK]
# Generating QR code 1745[OK]
# Generating QR code 1746[OK]
# Generating QR code 1747[OK]
# Generating QR code 1748[OK]
# Generating QR code 1749[OK]
# Generating QR code 1750[OK]
# Generating QR code 1751[OK]
# Generating QR code 1752[OK]
# ...
# Generating QR code 3586[OK]
# Generating QR code 3587[OK]
# Generating QR code 3588[OK]
# Generating QR code 3589[OK]
# Generating QR code 3590[OK]
# Generating QR code 3591[OK]
# Generating QR code 3592[OK]
# Generating QR code 3593[OK]
# Generating QR code 3594[OK]
# Generating QR code 3595[OK]
# Generating QR code 3596[OK]
# Generating QR code 3597[OK]
# Generating QR code 3598[OK]
# Generating QR code 3599[OK]
# Generating QR code 3600[OK]
# Generating QR code 3601[OK]
# Generating QR code 3602[OK]
# Generating QR code 3603[OK]
# Generating QR code 3604[OK]
# Generating QR code 3605[OK]
# Generating QR code 3606[OK]
# Generating QR code 3607[OK]
# Generating QR code 3608[OK]
# Generating QR code 3609[OK]
# Generating QR code 3610[OK]
# Generating QR code 3611[OK]
# Generating QR code 3612[OK]
# Generating QR code 3613[OK]
# Generating QR code 3614[OK]
# Generating QR code 3615[OK]
# Generating QR code 3616[OK]
# Generating QR code 3617[OK]
# Generating QR code 3618[OK]
# Generating QR code 3619[OK]
# Generating QR code 3620[OK]
# Generating QR code 3621[OK]
# Generating QR code 3622[OK]
# Generating QR code 3623[OK]
# Generating QR code 3624[OK]
# Generating QR code 3625[OK]
# Generating QR code 3626[OK]
# Generating QR code 3627[OK]
# Generating QR code 3628[OK]
# Generating QR code 3629[OK]
# Generating QR code 3630[OK]
# Generating QR code 3631[OK]
# Generating QR code 3632[OK]
# Generating QR code 3633[OK]
# Generating QR code 3634[OK]
# Generating QR code 3635[OK]
# Generating QR code 3636[OK]
# Generating QR code 3637[OK]
# Generating QR code 3638[OK]
# Generating QR code 3639[OK]
# Generating QR code 3640[OK]
# Generating QR code 3641[OK]
# Generating QR code 3642[OK]
# Generating QR code 3643[OK]
# Generating QR code 3644[OK]
# Generating QR code 3645[OK]
# Generating QR code 3646[OK]
# Generating QR code 3647[OK]
# Generating QR code 3648[OK]
# Generating QR code 3649[OK]
# Generating QR code 3650[OK]
# Generating QR code 3651[OK]
# Generating QR code 3652[OK]
# Generating QR code 3653[OK]
# Generating QR code 3654[OK]
# Generating QR code 3655[OK]
# Generating QR code 3656[OK]
# Generating QR code 3657[OK]
# Generating QR code 3658[OK]
# Generating QR code 3659[OK]
# Generating QR code 3660[OK]
# Generating QR code 3661[OK]
# Generating QR code 3662[OK]
# Generating QR code 3663[OK]
# Generating QR code 3664[OK]
# Generating QR code 3665[OK]
# Generating QR code 3666[OK]
# Generating QR code 3667[OK]
# Generating QR code 3668[OK]
# Generating QR code 3669[OK]
# Generating QR code 3670[OK]
# Generating QR code 3671[OK]
# Generating QR code 3672[OK]
# Generating QR code 3673[OK]
# Generating QR code 3674[OK]
# Generating QR code 3675[OK]
# Generating QR code 3676[OK]
# Generating QR code 3677[OK]
# Generating QR code 3678[OK]
# Generating QR code 3679[OK]
# Generating QR code 3680[OK]
# Generating QR code 3681[OK]
# Generating QR code 3682[OK]
# Generating QR code 3683[OK]
# Generating QR code 3684[OK]
# Generating QR code 3685[OK]
# Generating QR code 3686[OK]
# Generating QR code 3687[OK]
# Generating QR code 3688[OK]
# Generating QR code 3689[OK]
# Generating QR code 3690[OK]
# Generating QR code 3691[OK]
# Generating QR code 3692[OK]
# Generating QR code 3693[OK]
# Generating QR code 3694[OK]
# Generating QR code 3695[OK]
# Generating QR code 3696[OK]
# Generating QR code 3697[OK]
# Generating QR code 3698[OK]
# Generating QR code 3699[OK]
# Generating QR code 3700[OK]
# Generating QR code 3701[OK]
# Generating QR code 3702[OK]
# Generating QR code 3703[OK]
# Generating QR code 3704[OK]
# Generating QR code 3705[OK]
# Generating QR code 3706[OK]
# Generating QR code 3707[OK]
# Generating QR code 3708[OK]
# Generating QR code 3709[OK]
# Generating QR code 3710[OK]
# Generating QR code 3711[OK]
# Generating QR code 3712[OK]
# Generating QR code 3713[OK]
# Generating QR code 3714[OK]
# Generating QR code 3715[OK]
# Generating QR code 3716[OK]
# Generating QR code 3717[OK]
# Generating QR code 3718[OK]
# Generating QR code 3719[OK]
# Generating QR code 3720[OK]
# Generating QR code 3721[OK]
# Generating QR code 3722[OK]
# Generating QR code 3723[OK]
# Generating QR code 3724[OK]
# Generating QR code 3725[OK]
# Generating QR code 3726[OK]
# Generating QR code 3727[OK]
# Generating QR code 3728[OK]
# Generating QR code 3729[OK]
# Generating QR code 3730[OK]
# Generating QR code 3731[OK]
# Generating QR code 3732[OK]
# Generating QR code 3733[OK]
# Generating QR code 3734[OK]
# Generating QR code 3735[OK]
# Generating QR code 3736[OK]
# Generating QR code 3737[OK]
# Generating QR code 3738[OK]
# Generating QR code 3739[OK]
# Generating QR code 3740[OK]
# Generating QR code 3741[OK]
# Generating QR code 3742[OK]
# Generating QR code 3743[OK]
# Generating QR code 3744[OK]
# Generating QR code 3745[OK]
# Generating QR code 3746[OK]
# Generating QR code 3747[OK]
# Generating QR code 3748[OK]
# Generating QR code 3749[OK]
# Generating QR code 3750[OK]
# Generating QR code 3751[OK]
# Generating QR code 3752[OK]
# Generating QR code 3753[OK]
# Generating QR code 3754[OK]
# Generating QR code 3755[OK]
# Generating QR code 3756[OK]
# Generating QR code 3757[OK]
# Generating QR code 3758[OK]
# Generating QR code 3759[OK]
# Generating QR code 3760[OK]
# Generating QR code 3761[OK]
# Generating QR code 3762[OK]
# Generating QR code 3763[OK]
# Generating QR code 3764[OK]
# Generating QR code 3765[OK]
# Generating QR code 3766[OK]
# Generating QR code 3767[OK]
# Generating QR code 3768[OK]
# Generating QR code 3769[OK]
# Generating QR code 3770[OK]
# Generating QR code 3771[OK]
# Generating QR code 3772[OK]
# Generating QR code 3773[OK]
# Generating QR code 3774[OK]
# Generating QR code 3775[OK]
# Generating QR code 3776[OK]
# Generating QR code 3777[OK]
# Generating QR code 3778[OK]
# Generating QR code 3779[OK]
# Generating QR code 3780[OK]
# Generating QR code 3781[OK]
# Generating QR code 3782[OK]
# Generating QR code 3783[OK]
# Generating QR code 3784[OK]
# Generating QR code 3785[OK]
# Generating QR code 3786[OK]
# Generating QR code 3787[OK]
# Generating QR code 3788[OK]
# Generating QR code 3789[OK]
# Generating QR code 3790[OK]
# Generating QR code 3791[OK]
# Generating QR code 3792[OK]
# Generating QR code 3793[OK]
# Generating QR code 3794[OK]
# Generating QR code 3795[OK]
# Generating QR code 3796[OK]
# Generating QR code 3797[OK]
# Generating QR code 3798[OK]
# Generating QR code 3799[OK]
# Generating QR code 3800[OK]
# Generating QR code 3801[OK]
# Generating QR code 3802[OK]
# Generating QR code 3803[OK]
# Generating QR code 3804[OK]
# Generating QR code 3805[OK]
# Generating QR code 3806[OK]
# Generating QR code 3807[OK]
# Generating QR code 3808[OK]
# Generating QR code 3809[OK]
# Generating QR code 3810[OK]
# Generating QR code 3811[OK]
# Generating QR code 3812[OK]
# Generating QR code 3813[OK]
# Generating QR code 3814[OK]
# Generating QR code 3815[OK]
# Generating QR code 3816[OK]
# Generating QR code 3817[OK]
# Generating QR code 3818[OK]
# Generating QR code 3819[OK]
# Generating QR code 3820[OK]
# Generating QR code 3821[OK]
# Generating QR code 3822[OK]
# Generating QR code 3823[OK]
# Generating QR code 3824[OK]
# Generating QR code 3825[OK]
# Generating QR code 3826[OK]
# Generating QR code 3827[OK]
# Generating QR code 3828[OK]
# Generating QR code 3829[OK]
# Generating QR code 3830[OK]
# Generating QR code 3831[OK]
# Generating QR code 3832[OK]
# Generating QR code 3833[OK]
# Generating QR code 3834[OK]
# Generating QR code 3835[OK]
# Generating QR code 3836[OK]
# Generating QR code 3837[OK]
# Generating QR code 3838[OK]
# Generating QR code 3839[OK]
# Generating QR code 3840[OK]
# Generating QR code 3841[OK]
# Generating QR code 3842[OK]
# Generating QR code 3843[OK]
# Generating QR code 3844[OK]
# Generating QR code 3845[OK]
# Generating QR code 3846[OK]
# Generating QR code 3847[OK]
# Generating QR code 3848[OK]
# Generating QR code 3849[OK]
# Generating QR code 3850[OK]
# Generating QR code 3851[OK]
# Generating QR code 3852[OK]
# Generating QR code 3853[OK]
# Generating QR code 3854[OK]
# Generating QR code 3855[OK]
# Generating QR code 3856[OK]
# Generating QR code 3857[OK]
# Generating QR code 3858[OK]
# Generating QR code 3859[OK]
# Generating QR code 3860[OK]
# Generating QR code 3861[OK]
# Generating QR code 3862[OK]
# Generating QR code 3863[OK]
# Generating QR code 3864[OK]
# Generating QR code 3865[OK]
# Generating QR code 3866[OK]
# Generating QR code 3867[OK]
# Generating QR code 3868[OK]
# Generating QR code 3869[OK]
# Generating QR code 3870[OK]
# Generating QR code 3871[OK]
# Generating QR code 3872[OK]
# Generating QR code 3873[OK]
# Generating QR code 3874[OK]
# Generating QR code 3875[OK]
# Generating QR code 3876[OK]
# Generating QR code 3877[OK]
# Generating QR code 3878[OK]
# Generating QR code 3879[OK]
# Generating QR code 3880[OK]
# Generating QR code 3881[OK]
# Generating QR code 3882[OK]
# Generating QR code 3883[OK]
# Generating QR code 3884[OK]
# Generating QR code 3885[OK]
# Generating QR code 3886[OK]
# Generating QR code 3887[OK]
# Generating QR code 3888[OK]
# Generating QR code 3889[OK]
# Generating QR code 3890[OK]
# Generating QR code 3891[OK]
# Generating QR code 3892[OK]
# Generating QR code 3893[OK]
# Generating QR code 3894[OK]
# Generating QR code 3895[OK]
# Generating QR code 3896[OK]
# Generating QR code 3897[OK]
# Generating QR code 3898[OK]
# Generating QR code 3899[OK]
# Generating QR code 3900[OK]
# Generating QR code 3901[OK]
# Generating QR code 3902[OK]
# Generating QR code 3903[OK]
# Generating QR code 3904[OK]
# Generating QR code 3905[OK]
# Generating QR code 3906[OK]
# Generating QR code 3907[OK]
# Generating QR code 3908[OK]
# Generating QR code 3909[OK]
# Generating QR code 3910[OK]
# Generating QR code 3911[OK]
# Generating QR code 3912[OK]
# Generating QR code 3913[OK]
# Generating QR code 3914[OK]
# Generating QR code 3915[OK]
# Generating QR code 3916[OK]
# Generating QR code 3917[OK]
# Generating QR code 3918[OK]
# Generating QR code 3919[OK]
# Generating QR code 3920[OK]
# Generating QR code 3921[OK]
# Generating QR code 3922[OK]
# Generating QR code 3923[OK]
# Generating QR code 3924[OK]
# Generating QR code 3925[OK]
# Generating QR code 3926[OK]
# Generating QR code 3927[OK]
# Generating QR code 3928[OK]
# Generating QR code 3929[OK]
# Generating QR code 3930[OK]
# Generating QR code 3931[OK]
# Generating QR code 3932[OK]
# Generating QR code 3933[OK]
# Generating QR code 3934[OK]
# Generating QR code 3935[OK]
# Generating QR code 3936[OK]
# Generating QR code 3937[OK]
# Generating QR code 3938[OK]
# Generating QR code 3939[OK]
# Generating QR code 3940[OK]
# Generating QR code 3941[OK]
# Generating QR code 3942[OK]
# Generating QR code 3943[OK]
# Generating QR code 3944[OK]
# Generating QR code 3945[OK]
# Generating QR code 3946[OK]
# Generating QR code 3947[OK]
# Generating QR code 3948[OK]
# Generating QR code 3949[OK]
# Generating QR code 3950[OK]
# Generating QR code 3951[OK]
# Generating QR code 3952[OK]
# Generating QR code 3953[OK]
# Generating QR code 3954[OK]
# Generating QR code 3955[OK]
# Generating QR code 3956[OK]
# Generating QR code 3957[OK]
# Generating QR code 3958[OK]
# Generating QR code 3959[OK]
# Generating QR code 3960[OK]
# Generating QR code 3961[OK]
# Generating QR code 3962[OK]
# Generating QR code 3963[OK]
# Generating QR code 3964[OK]
# Generating QR code 3965[OK]
# Generating QR code 3966[OK]
# Generating QR code 3967[OK]
# Generating QR code 3968[OK]
# Generating QR code 3969[OK]
# Generating QR code 3970[OK]
# Generating QR code 3971[OK]
# Generating QR code 3972[OK]
# Generating QR code 3973[OK]
# Generating QR code 3974[OK]
# Generating QR code 3975[OK]
# Generating QR code 3976[OK]
# Generating QR code 3977[OK]
# Generating QR code 3978[OK]
# Generating QR code 3979[OK]
# Generating QR code 3980[OK]
# Generating QR code 3981[OK]
# Generating QR code 3982[OK]
# Generating QR code 3983[OK]
# Generating QR code 3984[OK]
# Generating QR code 3985[OK]
# Generating QR code 3986[OK]
# Generating QR code 3987[OK]
# Generating QR code 3988[OK]
# Generating QR code 3989[OK]
# Generating QR code 3990[OK]
# Generating QR code 3991[OK]
# Generating QR code 3992[OK]
# Generating QR code 3993[OK]
# Generating QR code 3994[OK]
# Generating QR code 3995[OK]
# Generating QR code 3996[OK]
# Generating QR code 3997[OK]
# Generating QR code 3998[OK]
# Generating QR code 3999[OK]
# Generating QR code 4000[OK]
# Generating QR code 4001[OK]
# Generating QR code 4002[OK]
# Generating QR code 4003[OK]
# Generating QR code 4004[OK]
# Generating QR code 4005[OK]
# Generating QR code 4006[OK]
# Generating QR code 4007[OK]
# Generating QR code 4008[OK]
# Generating QR code 4009[OK]
# Generating QR code 4010[OK]
# Generating QR code 4011[OK]
# Generating QR code 4012[OK]
# Generating QR code 4013[OK]
# Generating QR code 4014[OK]
# Generating QR code 4015[OK]
# Generating QR code 4016[OK]
# Generating QR code 4017[OK]
# Generating QR code 4018[OK]
# Generating QR code 4019[OK]
# Generating QR code 4020[OK]
# Generating QR code 4021[OK]
# Generating QR code 4022[OK]
# Generating QR code 4023[OK]
# Generating QR code 4024[OK]
# Generating QR code 4025[OK]
# Generating QR code 4026[OK]
# Generating QR code 4027[OK]
# Generating QR code 4028[OK]
# Generating QR code 4029[OK]
# Generating QR code 4030[OK]
# Generating QR code 4031[OK]
# Generating QR code 4032[OK]
# Generating QR code 4033[OK]
# Generating QR code 4034[OK]
# Generating QR code 4035[OK]
# Generating QR code 4036[OK]
# Generating QR code 4037[OK]
# Generating QR code 4038[OK]
# Generating QR code 4039[OK]
# Generating QR code 4040[OK]
# Generating QR code 4041[OK]
# Generating QR code 4042[OK]
# Generating QR code 4043[OK]
# Generating QR code 4044[OK]
# Generating QR code 4045[OK]
# Generating QR code 4046[OK]
# Generating QR code 4047[OK]
# Generating QR code 4048[OK]
# Generating QR code 4049[OK]
# Generating QR code 4050[OK]
# Generating QR code 4051[OK]
# Generating QR code 4052[OK]
# Generating QR code 4053[OK]
# Generating QR code 4054[OK]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 with open("test_file.JPG", "rb") as f:
#       2     data = f.read()
# ----> 4 bin_to_qr(data, folder_path='out_path/'  ,chunk_size=2048, box_size=1, border=5)
#
# Cell In[7], line 10, in bin_to_qr(data, chunk_size, folder_path, filename_prefix, box_size, border)
#       8 qr = qrcode.QRCode(version=40, error_correction=qrcode.constants.ERROR_CORRECT_L, box_size=box_size, border=border)
#       9 qr.add_data(f"{i}/{total_chunks}:{chunk}")
# ---> 10 qr.make(fit=False)
#      11 print(f"Generating QR code {i}", end="")
#      12 img = qr.make_image(fill_color="black", back_color="white")
#
# File ~/.local/lib/python3.10/site-packages/qrcode/main.py:161, in QRCode.make(self, fit)
#     159     self.best_fit(start=self.version)
#     160 if self.mask_pattern is None:
# --> 161     self.makeImpl(False, self.best_mask_pattern())
#     162 else:
#     163     self.makeImpl(False, self.mask_pattern)
#
# File ~/.local/lib/python3.10/site-packages/qrcode/main.py:249, in QRCode.best_mask_pattern(self)
#     246 pattern = 0
#     248 for i in range(8):
# --> 249     self.makeImpl(True, i)
#     251     lost_point = util.lost_point(self.modules)
#     253     if i == 0 or min_lost_point > lost_point:
#
# File ~/.local/lib/python3.10/site-packages/qrcode/main.py:188, in QRCode.makeImpl(self, test, mask_pattern)
#     185     self.setup_type_number(test)
#     187 if self.data_cache is None:
# --> 188     self.data_cache = util.create_data(
#     189         self.version, self.error_correction, self.data_list
#     190     )
#     191 self.map_data(self.data_cache, mask_pattern)
#
# File ~/.local/lib/python3.10/site-packages/qrcode/util.py:585, in create_data(version, error_correction, data_list)
#     582     else:
#     583         buffer.put(PAD1, 8)
# --> 585 return create_bytes(buffer, rs_blocks)
#
# File ~/.local/lib/python3.10/site-packages/qrcode/util.py:528, in create_bytes(buffer, rs_blocks)
#     524         rsPoly = rsPoly * base.Polynomial([1, base.gexp(i)], 0)
#     526 rawPoly = base.Polynomial(current_dc, len(rsPoly) - 1)
# --> 528 modPoly = rawPoly % rsPoly
#     529 current_ec = []
#     530 mod_offset = len(modPoly) - ecCount
#
# File ~/.local/lib/python3.10/site-packages/qrcode/base.py:279, in Polynomial.__mod__(self, other)
#     276 if difference < 0:
#     277     return self
# --> 279 ratio = glog(self[0]) - glog(other[0])
#     281 num = [
#     282     item ^ gexp(glog(other_item) + ratio)
#     283     for item, other_item in zip(self, other)
#     284 ]
#     285 if difference:
#
# File ~/.local/lib/python3.10/site-packages/qrcode/base.py:236, in glog(n)
#     234 def glog(n):
#     235     if n < 1:  # pragma: no cover
# --> 236         raise ValueError(f"glog({n})")
#     237     return LOG_TABLE[n]
#
# ValueError: glog(0)

# %%
test_file_compressed = qr_to_bin(folder_path='out_path/')

# %%
test_file = decompress_bytes(test_file_compressed)
with open( "test_file_out.JPG", "wb") as f:
     f.write(test_file)
